# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('movies_metadata.csv')
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/1532675202.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('movies_metadata.csv')

# %%
data[['overview','genres']].head()
# data.head()
# Out:
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
keywords_data = pd.read_csv('keywords.csv')
keywords_data.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
data = data.drop(data[~data['id'].astype(str).str.isdigit()].index)
data['id'] = data['id'].astype(int)

keywords_data = keywords_data.drop(data[~data['id'].astype(str).str.isdigit()].index)
keywords_data['id'] = keywords_data['id'].astype(int)

combinedData = pd.merge(data,keywords_data,on='id',how='outer')

# %%
filteredData = combinedData[['id','title','genres','overview','keywords','tagline','popularity']]
filteredData.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
#                                              tagline popularity
# 0                                                NaN  21.946943
# 1          Roll the dice and unleash the excitement!  17.015539
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129
# 3  Friends are the people who let you be yourself...   3.859495
# 4  Just When His World Is Back To Normal... He's ...   8.387519

# %%
import ast

filteredData.keywords=filteredData.keywords.fillna('[{}]')

keywordsList=[]
for index,row in filteredData.keywords.iteritems():
    kStr=''

    listofDict=ast.literal_eval(row)
    for dic in listofDict:
        if('name' in dic.keys()):
            kStr=kStr+','+dic['name'] 
    kStr=kStr.strip(',') # trim leading ;
    keywordsList.append(kStr)

tempDF=pd.DataFrame(keywordsList,columns=['keywords'])
filteredData.keywords=tempDF['keywords']
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/18641195.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData.keywords=filteredData.keywords.fillna('[{}]')
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/18641195.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData.keywords=tempDF['keywords']

# %%
filteredData.genres=filteredData.genres.fillna('[{}]')

keywordsList=[]
for index,row in filteredData.genres.iteritems():
    kStr=''

    listofDict=ast.literal_eval(row)
    for dic in listofDict:
        if('name' in dic.keys()):
            kStr=kStr+','+dic['name'] 
    kStr=kStr.strip(',') # trim leading ;
    keywordsList.append(kStr)

tempDF=pd.DataFrame(keywordsList,columns=['genres'])
filteredData.genres=tempDF['genres']
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/3891226718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData.genres=filteredData.genres.fillna('[{}]')
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/3891226718.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData.genres=tempDF['genres']

# %%
filteredData.head()
# Out:
#       id                        title                    genres  \
# 0    862                    Toy Story   Animation,Comedy,Family
# 1   8844                      Jumanji  Adventure,Fantasy,Family
# 2  15602             Grumpier Old Men            Romance,Comedy
# 3  31357            Waiting to Exhale      Comedy,Drama,Romance
# 4  11862  Father of the Bride Part II                    Comedy
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                             keywords  \
# 0  jealousy,toy,boy,friendship,friends,rivalry,bo...
# 1  board game,disappearance,based on children's b...
# 2   fishing,best friend,duringcreditsstinger,old men
# 3  based on novel,interracial relationship,single...
# 4  baby,midlife crisis,confidence,aging,daughter,...
#
#                                              tagline popularity
# 0                                                NaN  21.946943
# 1          Roll the dice and unleash the excitement!  17.015539
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129
# 3  Friends are the people who let you be yourself...   3.859495
# 4  Just When His World Is Back To Normal... He's ...   8.387519

# %%
# !pip install nltk
import nltk
import string
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)
    filtered_text = [lemmatizer.lemmatize(word.lower(), pos ='v') for word in word_tokens if word not in stop_words]
    return filtered_text
 
filteredData['pre-processed'] = filteredData['overview'].astype(str)
filteredData['pre-processed'] = filteredData['pre-processed'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/snehith/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/snehith/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/snehith/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/snehith/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/3224922070.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['pre-processed'] = filteredData['overview'].astype(str)
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/3224922070.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['pre-processed'] = filteredData['pre-processed'].apply(remove_stopwords)

# %%
filteredData.head()
# Out:
#       id                        title                    genres  \
# 0    862                    Toy Story   Animation,Comedy,Family
# 1   8844                      Jumanji  Adventure,Fantasy,Family
# 2  15602             Grumpier Old Men            Romance,Comedy
# 3  31357            Waiting to Exhale      Comedy,Drama,Romance
# 4  11862  Father of the Bride Part II                    Comedy
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                             keywords  \
# 0  jealousy,toy,boy,friendship,friends,rivalry,bo...
# 1  board game,disappearance,based on children's b...
# 2   fishing,best friend,duringcreditsstinger,old men
# 3  based on novel,interracial relationship,single...
# 4  baby,midlife crisis,confidence,aging,daughter,...
#
#                                              tagline popularity  \
# 0                                                NaN  21.946943
# 1          Roll the dice and unleash the excitement!  17.015539
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129
# 3  Friends are the people who let you be yourself...   3.859495
# 4  Just When His World Is Back To Normal... He's ...   8.387519
#
#                                        pre-processed
# 0  [lead, woody, ,, andy, 's, toy, live, happily,...
# 1  [when, siblings, judy, peter, discover, enchan...
# 2  [a, family, wed, reignite, ancient, feud, next...
# 3  [cheat, ,, mistreat, step, ,, women, hold, bre...
# 4  [just, george, bank, recover, daughter, 's, we...

# %%
filteredData['genre tokens'] = filteredData['genres'].str.replace(",", " ")
filteredData['keywords tokens'] = filteredData['keywords'].str.replace(",", " ")
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/4024346985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['genre tokens'] = filteredData['genres'].str.replace(",", " ")
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/4024346985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['keywords tokens'] = filteredData['keywords'].str.replace(",", " ")

# %%
filteredData
# Out:
#            id                        title                    genres  \
# 0         862                    Toy Story   Animation,Comedy,Family
# 1        8844                      Jumanji  Adventure,Fantasy,Family
# 2       15602             Grumpier Old Men            Romance,Comedy
# 3       31357            Waiting to Exhale      Comedy,Drama,Romance
# 4       11862  Father of the Bride Part II                    Comedy
# ...       ...                          ...                       ...
# 46478  439050                       Subdue              Drama,Family
# 46479  111109          Century of Birthing                     Drama
# 46480   67758                     Betrayal     Action,Drama,Thriller
# 46481  227506             Satan Triumphant
# 46482  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 46478        Rising and falling between a man and woman.
# 46479  An artist struggles to finish his work while a...
# 46480  When one of her hits goes wrong, a professiona...
# 46481  In a small town live two brothers, one a minis...
# 46482  50 years after decriminalisation of homosexual...
#
#                                                 keywords  \
# 0      jealousy,toy,boy,friendship,friends,rivalry,bo...
# 1      board game,disappearance,based on children's b...
# 2       fishing,best friend,duringcreditsstinger,old men
# 3      based on novel,interracial relationship,single...
# 4      baby,midlife crisis,confidence,aging,daughter,...
# ...                                                  ...
# 46478                                        tragic love
# 46479                                  artist,play,pinoy
# 46480
# 46481
# 46482
#
#                                                  tagline popularity  \
# 0                                                    NaN  21.946943
# 1              Roll the dice and unleash the excitement!  17.015539
# 2      Still Yelling. Still Fighting. Still Ready for...    11.7129
# 3      Friends are the people who let you be yourself...   3.859495
# 4      Just When His World Is Back To Normal... He's ...   8.387519
# ...                                                  ...        ...
# 46478         Rising and falling between a man and woman   0.072051
# 46479                                                NaN   0.178241
# 46480                             A deadly game of wits.   0.903007
# 46481                                                NaN   0.003503
# 46482                                                NaN   0.163015
#
#                                            pre-processed  \
# 0      [lead, woody, ,, andy, 's, toy, live, happily,...
# 1      [when, siblings, judy, peter, discover, enchan...
# 2      [a, family, wed, reignite, ancient, feud, next...
# 3      [cheat, ,, mistreat, step, ,, women, hold, bre...
# 4      [just, george, bank, recover, daughter, 's, we...
# ...                                                  ...
# 46478                        [rise, fall, man, woman, .]
# 46479  [an, artist, struggle, finish, work, storyline...
# 46480  [when, one, hit, go, wrong, ,, professional, a...
# 46481  [in, small, town, live, two, brothers, ,, one,...
# 46482  [50, years, decriminalisation, homosexuality, ...
#
#                    genre tokens  \
# 0       Animation Comedy Family
# 1      Adventure Fantasy Family
# 2                Romance Comedy
# 3          Comedy Drama Romance
# 4                        Comedy
# ...                         ...
# 46478              Drama Family
# 46479                     Drama
# 46480     Action Drama Thriller
# 46481
# 46482
#
#                                          keywords tokens
# 0      jealousy toy boy friendship friends rivalry bo...
# 1      board game disappearance based on children's b...
# 2       fishing best friend duringcreditsstinger old men
# 3      based on novel interracial relationship single...
# 4      baby midlife crisis confidence aging daughter ...
# ...                                                  ...
# 46478                                        tragic love
# 46479                                  artist play pinoy
# 46480
# 46481
# 46482
#
# [46483 rows x 10 columns]

# %%
filteredData['overview tokens'] = filteredData['pre-processed'].apply(lambda x: ' '.join(x))
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/2448553436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['overview tokens'] = filteredData['pre-processed'].apply(lambda x: ' '.join(x))

# %%
filteredData
# Out:
#            id                        title                    genres  \
# 0         862                    Toy Story   Animation,Comedy,Family
# 1        8844                      Jumanji  Adventure,Fantasy,Family
# 2       15602             Grumpier Old Men            Romance,Comedy
# 3       31357            Waiting to Exhale      Comedy,Drama,Romance
# 4       11862  Father of the Bride Part II                    Comedy
# ...       ...                          ...                       ...
# 46478  439050                       Subdue              Drama,Family
# 46479  111109          Century of Birthing                     Drama
# 46480   67758                     Betrayal     Action,Drama,Thriller
# 46481  227506             Satan Triumphant
# 46482  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 46478        Rising and falling between a man and woman.
# 46479  An artist struggles to finish his work while a...
# 46480  When one of her hits goes wrong, a professiona...
# 46481  In a small town live two brothers, one a minis...
# 46482  50 years after decriminalisation of homosexual...
#
#                                                 keywords  \
# 0      jealousy,toy,boy,friendship,friends,rivalry,bo...
# 1      board game,disappearance,based on children's b...
# 2       fishing,best friend,duringcreditsstinger,old men
# 3      based on novel,interracial relationship,single...
# 4      baby,midlife crisis,confidence,aging,daughter,...
# ...                                                  ...
# 46478                                        tragic love
# 46479                                  artist,play,pinoy
# 46480
# 46481
# 46482
#
#                                                  tagline popularity  \
# 0                                                    NaN  21.946943
# 1              Roll the dice and unleash the excitement!  17.015539
# 2      Still Yelling. Still Fighting. Still Ready for...    11.7129
# 3      Friends are the people who let you be yourself...   3.859495
# 4      Just When His World Is Back To Normal... He's ...   8.387519
# ...                                                  ...        ...
# 46478         Rising and falling between a man and woman   0.072051
# 46479                                                NaN   0.178241
# 46480                             A deadly game of wits.   0.903007
# 46481                                                NaN   0.003503
# 46482                                                NaN   0.163015
#
#                                            pre-processed  \
# 0      [lead, woody, ,, andy, 's, toy, live, happily,...
# 1      [when, siblings, judy, peter, discover, enchan...
# 2      [a, family, wed, reignite, ancient, feud, next...
# 3      [cheat, ,, mistreat, step, ,, women, hold, bre...
# 4      [just, george, bank, recover, daughter, 's, we...
# ...                                                  ...
# 46478                        [rise, fall, man, woman, .]
# 46479  [an, artist, struggle, finish, work, storyline...
# 46480  [when, one, hit, go, wrong, ,, professional, a...
# 46481  [in, small, town, live, two, brothers, ,, one,...
# 46482  [50, years, decriminalisation, homosexuality, ...
#
#                    genre tokens  \
# 0       Animation Comedy Family
# 1      Adventure Fantasy Family
# 2                Romance Comedy
# 3          Comedy Drama Romance
# 4                        Comedy
# ...                         ...
# 46478              Drama Family
# 46479                     Drama
# 46480     Action Drama Thriller
# 46481
# 46482
#
#                                          keywords tokens  \
# 0      jealousy toy boy friendship friends rivalry bo...
# 1      board game disappearance based on children's b...
# 2       fishing best friend duringcreditsstinger old men
# 3      based on novel interracial relationship single...
# 4      baby midlife crisis confidence aging daughter ...
# ...                                                  ...
# 46478                                        tragic love
# 46479                                  artist play pinoy
# 46480
# 46481
# 46482
#
#                                          overview tokens
# 0      lead woody , andy 's toy live happily room and...
# 1      when siblings judy peter discover enchant boar...
# 2      a family wed reignite ancient feud next-door n...
# 3      cheat , mistreat step , women hold breath , wa...
# 4      just george bank recover daughter 's wed , rec...
# ...                                                  ...
# 46478                              rise fall man woman .
# 46479  an artist struggle finish work storyline cult ...
# 46480  when one hit go wrong , professional assassin ...
# 46481  in small town live two brothers , one minister...
# 46482  50 years decriminalisation homosexuality uk , ...
#
# [46483 rows x 11 columns]

# %%
filteredData['tokens'] = filteredData['genre tokens'] +" "+ filteredData['keywords tokens'] +" "+ filteredData['overview tokens']
filteredData['complete_string'] = filteredData['title'] + " "+ filteredData['overview'] +" "+ " "+ filteredData['tagline']
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/1546516904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['tokens'] = filteredData['genre tokens'] +" "+ filteredData['keywords tokens'] +" "+ filteredData['overview tokens']
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/1546516904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filteredData['complete_string'] = filteredData['title'] + " "+ filteredData['overview'] +" "+ " "+ filteredData['tagline']

# %%
# filteredData = filteredData.head(10)

# %%
import string
regular_punct = list(string.punctuation)
def remove_punctuation(text,punct_list):
    for punc in punct_list:
        if punc in text:
            text = text.replace(punc, ' ')
            
    text = ' '.join( [w for w in text.split() if len(w)>1] )
    return text.strip()

a= remove_punctuation(filteredData["tokens"][0],regular_punct)
# filteredData["tokens"][0].split(" ").remove
print(a)
# Out:
# Animation Comedy Family jealousy toy boy friendship friends rivalry boy next door new toy toy comes to life lead woody andy toy live happily room andy birthday bring buzz lightyear onto scene afraid lose place andy heart woody plot buzz but circumstances separate buzz woody owner duo eventually learn put aside differences

# %%
# your code here
import math
from collections import defaultdict
import copy
import math

import itertools
import pandas as pd

def convert_to_df(list_of_songs):
  set_list = list(list_of_songs)
  df = pd.DataFrame(list_of_songs, columns = ['title'] )
  df['Rank'] = range(1, len(list_of_songs) + 1)
  return df

def return_matching_songs(query, search_token_song_map):
  song_ids = set()
  result_song_ids = set()
  query_words = query.split(" ")
  flag = True
#   print(search_token_song_map)
  for query_word in query_words:
    if flag:
      song_ids.update(search_token_song_map[query_word])
      flag = False
    else:
      song_ids = song_ids.intersection(search_token_song_map[query_word])
  song_ids = sorted(song_ids)
  # set_list = list(song_ids)
  # df = pd.DataFrame(set_list, columns = ['song'] )
  # df['Rank'] = range(1, len(set_list) + 1)
  df = convert_to_df(song_ids)
  return df

def list_of_tokens(data):  
  tokens = {}
  individual_tokens = []
  row_with_duplicate_tokens = []
  vector_magnitude = []
  words_count = []
  for row in data['tokens']:
    # print(row)
    # print(row.split(' '))
    row_words = row.lower().split(' ')
    row_tokens = {}
    row_words_count = len(row_words)
    row_magnitude = 0
    list_tokens = set()
    for word in row_words:
      list_tokens.add(word)
      if word in tokens:
        tokens[word] = tokens[word]+1
      else:
        tokens[word] = 1
      if word in row_tokens:
        row_tokens[word] = row_tokens[word]+1
      else:
        row_tokens[word] = 1
    
    for key, val in row_tokens.items():
      row_magnitude = row_magnitude + (val*val)
      row_magnitude = math.sqrt(row_magnitude)
    vector_magnitude.append(row_magnitude)
    individual_tokens.append(list_tokens)
    words_count.append(row_words_count)
    row_with_duplicate_tokens.append(row_tokens.items())
    # index = index+1
  data['Tokens'] = individual_tokens
  data['TokensDictionary'] = row_with_duplicate_tokens
  data['Magnitude'] = vector_magnitude
  data['WordCount'] = words_count
  # tokens.update(data.apply(lambda x: x.split(' ')))
  tokens = sorted(tokens.items(), key=lambda x: x[1], reverse=True)
  return tokens

def build_index_token_map(data):
  index_token_map = {}
  for index, row in data.iterrows():
    for token in row['Tokens']:
      if token not in index_token_map:
        index_token_map[token] = set()
      index_token_map[token].add(row['title'])
    # print(row['song'], row['Tokens'])
  return index_token_map

def convert_to_df(list_of_songs):
  set_list = list(list_of_songs)
  df = pd.DataFrame(list_of_songs, columns = ['title'] )
  df['Rank'] = range(1, len(list_of_songs) + 1)
  return df

def song_id_token_map(data):
  song_token_map = defaultdict()
  for index, row in data.iterrows():
    res = defaultdict()
    for (k,v) in row['TokensDictionary']:
        res[k] = v
    song_token_map[row['title']] = res
#   print(song_token_map)
  return song_token_map


def compute_TFIDF(tf, df, N):
  # print(tf, df, N)
  # ans = 0
  if tf == 0:
    return 0 
  ans = 1 + math.log((tf),10)
  ans = ans*(math.log((N/df),10))
  return ans

def calc_all_docs_magnitude_basis_on_tfidf(data, boolean_search_index_map):
  map = {}
  total_N = len(data)
  tfidf_magnitude = []
  for index, row in data.iterrows():
    res = defaultdict()
    mag = 0
    for (k,v) in row['TokensDictionary']:
      res[k] = v
      mag = mag + math.pow(compute_TFIDF(v,len(boolean_search_index_map[k]),total_N),2)
    mag = math.sqrt(mag)
    tfidf_magnitude.append(mag)
    map[row['title']] = mag
  data['TFIDF_MAGNITUDE'] = tfidf_magnitude
  return map

def get_query_dict(query):
  user_query_words = query.split(" ")
  user_query_dict = {}
  for word in user_query_words:
    if word not in user_query_dict:
      user_query_dict[word] = 0
    user_query_dict[word] = user_query_dict[word]+1
  return user_query_dict

def get_query_magn(query):
  user_query_words = query.split(" ")
  user_query_dict = {}
  ans = 0
  for word in user_query_words:
    if word not in user_query_dict:
      user_query_dict[word] = 0
    user_query_dict[word] = user_query_dict[word]+1
  for key, val in user_query_dict.items():
    ans = ans + val*val
  return math.sqrt(ans)


def calc_all_docs_magnitude_basis_on_idf(data, boolean_search_index_map):
  map = {}
  total_N = len(data)
  # bm25_magnitude = []
  total_words = 0
  for index, row in data.iterrows():
    for (k,v) in row['TokensDictionary']:
      total_words = total_words+v
  return total_words

  for index, row in data.iterrows():
    res = defaultdict()
    mag = 0
    for (k,v) in row['TokensDictionary']:
      res[k] = v
      mag = mag + v
    mag = mag/total_words
    bm25_magnitude.append(mag)
    map[row['title']] = mag
  data['BM25_MAGNITUDE'] = bm25_magnitude
  return map

def get_song_word_map(data):
  song_word_map = defaultdict()
  for index, row in data.iterrows():
    song_word_map[row['title']] = row['WordCount']
  return song_word_map

def calc_idf_bm25(query, map, N):
  ans = math.log10(((N-len(map[query])+0.5)/(len(map[query])+0.5))+1)
  return ans

def calc_bm25_score(tf, avgdl, D, query, map, N):
  k_1 = 1.2
  b = 0.75
  num = tf * (k_1+1)
  den = (tf+(k_1*(1-b+(b*(D/avgdl)))))
  ans = calc_idf_bm25(query, map, N)
  ans = ans * (num/den)
  return ans


def return_five_matching_songs_with_bm25(query, data):
  lemmatize_and_remove_background_tokens_part3 = list_of_tokens(data)
  boolean_search_index_map_part3 = build_index_token_map(data)
#   print(boolean_search_index_map_part3)
  avgdl = calc_all_docs_magnitude_basis_on_idf(data, boolean_search_index_map_part3)
  total_docs = len(data) # N
  avgdl = avgdl/total_docs
  
  song_token_map = song_id_token_map(data)
#   print(song_token_map)

  song_ids_for_search = return_matching_songs(query,boolean_search_index_map_part3)
  current_query_dict = {}
  total_magnitudes_dict = calc_all_docs_magnitude_basis_on_tfidf(data, boolean_search_index_map_part3)
  song_word_map = get_song_word_map(data)
  query_mag = get_query_magn(query)
  for song in data['title'].tolist():
    score_bm25 = 0
    user_query_dict = get_query_dict(query)
    for query_word, freq in user_query_dict.items():  
      number_of_documents_with_query_word = len(boolean_search_index_map_part3[query_word])
      term_freq_in_cur_doc = 0
      if query_word in song_token_map[song]:
        term_freq_in_cur_doc = song_token_map[song][query_word]
      score_bm25 = score_bm25 + calc_bm25_score(term_freq_in_cur_doc, avgdl, song_word_map[song], query_word, boolean_search_index_map_part3, total_docs)
    current_query_dict[song] = score_bm25
    
  sorted_result_with_tfidf = sorted(current_query_dict.items(), key=lambda x: x[1], reverse=True)
  return sorted_result_with_tfidf

def bm25_search(user_query):
  user_query = user_query.lower()
  user_query.replace("and","")
  lemmatize_and_remove_background_vocals_part3 = filteredData
  res_of_bm25 = return_five_matching_songs_with_bm25(user_query, lemmatize_and_remove_background_vocals_part3)
  res_of_bm25_df = pd.DataFrame(res_of_bm25) 
  res_of_bm25_df

  res_of_bm25_df = res_of_bm25_df.rename(columns={0: 'title', 1: 'BM25'})
  # res_of_tfidf_df
  res_of_bm25_df['Rank'] = range(1, len(res_of_bm25_df) + 1)
  songs_for_query = pd.merge(left=res_of_bm25_df, right=filteredData, left_on='title', right_on = 'title')
  songs_for_query = songs_for_query[['Rank', 'BM25', 'title', 'tokens','popularity','complete_string']]
  return songs_for_query.head(50)

# %%
df = bm25_search("toy story")
# Out:
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/257247268.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Tokens'] = individual_tokens
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/257247268.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TokensDictionary'] = row_with_duplicate_tokens
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/257247268.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Magnitude'] = vector_magnitude
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/257247268.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['WordCount'] = words_count
# /var/folders/b2/jlt4b5p57_s5m_k_sn2rxpdm0000gp/T/ipykernel_25732/257247268.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TFIDF_MAGNITUDE'] = tfidf_magnitude

# %%
df.head(50)
# Out:
#     Rank      BM25                                              title  \
# 0      1  5.711096                                     Toy Reanimator
# 1      2  5.550642                                  Hawaiian Vacation
# 2      3  5.496301                         Toy Story That Time Forgot
# 3      4  5.468701                               Toy Story of Terror!
# 4      5  5.221234                       How the Toys Saved Christmas
# 5      6  5.161799                                        Toy Story 3
# 6      7  4.698710                                    Partysaurus Rex
# 7      8  4.577009                                     Small Soldiers
# 8      9  4.422698                                               Toys
# 9     10  4.419878        Silent Night, Deadly Night 5: The Toy Maker
# 10    11  4.263437                           Dollman vs. Demonic Toys
# 11    12  4.201046                                          Small Fry
# 12    13  4.103764                            The Mouse and His Child
# 13    14  4.096271                                        Toy Story 2
# 14    15  4.025560                                          Toy Story
# 15    16  4.022049                                               Alma
# 16    17  3.959952                                      Dolly Dearest
# 17    17  3.959952                                      Dolly Dearest
# 18    18  3.912982                     Mr. Magorium's Wonder Emporium
# 19    19  3.877929                                       Home Alone 3
# 20    20  3.828290                    Rudolph, the Red-Nosed Reindeer
# 21    21  3.803390                        The Transformers: The Movie
# 22    22  3.718371               The Life & Adventures of Santa Claus
# 23    22  3.718371               The Life & Adventures of Santa Claus
# 24    23  3.612933                         The Adventures of Buratino
# 25    23  3.612933                         The Adventures of Buratino
# 26    24  3.568262                                  The Christmas Toy
# 27    25  3.503289                                     Christmas Evil
# 28    26  3.482154        Plastic Galaxy: The Story of Star Wars Toys
# 29    26  3.482154        Plastic Galaxy: The Story of Star Wars Toys
# 30    27  3.426041                              The Phantom Tollbooth
# 31    28  3.426041                                         Macropolis
# 32    29  3.425304                               A LEGO Brickumentary
# 33    30  3.307535                            The Million Dollar Duck
# 34    31  3.247083                             Santa Claus: The Movie
# 35    32  3.162555                    Christmas Comes but Once a Year
# 36    33  3.158248                                              Wolfy
# 37    34  3.133961                      Annie Claus is Coming to Town
# 38    35  3.128274                                  Man Is Not a Bird
# 39    36  3.124060                                     Child's Play 3
# 40    37  3.094729                                        Rabbit Hole
# 41    38  3.074144    The Tangerine Bear: Home in Time for Christmas!
# 42    39  3.061895                                     Child's Play 2
# 43    40  3.057858                                         The Mascot
# 44    41  2.998275                         The Indian in the Cupboard
# 45    42  2.998275                                          Tormented
# 46    42  2.998275                                          Tormented
# 47    42  2.998275                                          Tormented
# 48    43  2.967446                      Puppet Master vs Demonic Toys
# 49    44  2.967446  Michael Bolton's Big, Sexy Valentine's Day Spe...
#
#                                                tokens popularity  \
# 0   Science Fiction Fantasy  set toy store special...   0.002385
# 1   Animation Family short toy story pixar animati...  11.315849
# 2   Animation Family toy short toy story during po...   8.609555
# 3   Animation Comedy Family halloween toys short w...   0.512025
# 4   Animation Family Foreign  when santa 's helper...   0.266335
# 5   Animation Family Comedy hostage college toy ba...   16.96647
# 6   Animation Comedy Family Fantasy tyrannosaurus ...   6.066171
# 7   Comedy Adventure Fantasy Science Fiction Actio...   10.03936
# 8   Fantasy Comedy Science Fiction brother brother...   5.923774
# 9   Horror Science Fiction killer robot sequel rob...   1.240357
# 10  Horror Thriller Science Fiction Action Fantasy...    1.05016
# 11  Animation Family fast food restaurant toys fas...   9.858179
# 12  Animation Drama Family  the mouse son two part...   0.754872
# 13  Animation Comedy Family museum prosecution ide...  17.547693
# 14  Animation Comedy Family jealousy toy boy frien...  21.946943
# 15  Animation Fantasy Mystery shop store window to...   1.700431
# 16  Horror killer doll an american family move mex...   1.686426
# 17  Horror killer doll an american family move mex...   1.686426
# 18  Comedy magic fantasy darkness toy sell faith p...   8.696467
# 19  Comedy Family parent child relationship burgla...    8.04209
# 20  Animation Family winter adventure kids christm...   7.129761
# 21  Animation toy transformation based on toy tran...   6.759181
# 22  Animation Family  the great ak call council im...   0.005351
# 23  Animation Family  base popular book l. frank b...   0.635649
# 24  Family Fantasy Adventure  a wooden boy buratin...    1.00512
# 25  Family Adventure Animation Fantasy  a wooden b...   0.667698
# 26  Animation Family holiday musical christmas eve...   0.923952
# 27  Drama Horror santa claus hospital church kille...   8.952589
# 28  Documentary pop culture documentary toys space...   1.168756
# 29  Documentary pop culture documentary toys space...   1.168756
# 30  Fantasy Animation Adventure boy car toy car to...   1.567121
# 31  Animation  macropolis story two toy discard fa...   0.025827
# 32  Documentary pop culture fan culture documentar...   4.201151
# 33  Comedy Family  professor dooley take home duck...   0.808654
# 34  Family Fantasy Adventure Science Fiction Comed...  11.690532
# 35    at orphanage , children sad receive break to...   0.109407
# 36  Drama  there two : mother girl . they name . a...   0.301323
# 37  TV Movie Family holiday this year , santa ’ da...   0.368966
# 38  Drama love triangle circus beethoven engineer ...   0.552623
# 39  Thriller Horror Action recruit puppet killer d...  24.515462
# 40  Drama loss of son trauma toy marriage grief me...   7.007993
# 41  Animation Family toy friendship teddy bear thr...   1.408414
# 42  Drama Horror faithlessness puppet killer toys ...  14.310479
# 43  Fantasy Animation  a toy stuff dog sew togethe...   0.518636
# 44  Adventure Family Fantasy cupboard games puppet...  10.673296
# 45  Horror island lighthouse a jazz pianist ( rich...    0.93057
# 46  Comedy Horror suicide drowning bullying swimmi...   7.481106
# 47  Horror horror movie alternate world stuffed to...   0.511015
# 48  Horror evil doll a group toymakers seek use an...   1.945492
# 49  Comedy Music valentine's day after santa tell ...   0.789799
#
#                                       complete_string
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Toy Story of Terror! What starts out as a fun ...
# 4                                                 NaN
# 5   Toy Story 3 Woody, Buzz, and the rest of Andy'...
# 6   Partysaurus Rex When Rex finds himself left be...
# 7   Small Soldiers When missile technology is used...
# 8   Toys Leslie Zevo is a fun-loving inventor who ...
# 9   Silent Night, Deadly Night 5: The Toy Maker A ...
# 10  Dollman vs. Demonic Toys The Demonic Toys are ...
# 11                                                NaN
# 12                                                NaN
# 13  Toy Story 2 Andy heads off to Cowboy Camp, lea...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Mr. Magorium's Wonder Emporium Molly Mahoney i...
# 19  Home Alone 3 9-year-old Alex Pruitt is home al...
# 20  Rudolph, the Red-Nosed Reindeer Sam the snowma...
# 21  The Transformers: The Movie The Autobots must ...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Christmas Evil A toy factory worker, mentally ...
# 28  Plastic Galaxy: The Story of Star Wars Toys Pl...
# 29  Plastic Galaxy: The Story of Star Wars Toys Pl...
# 30  The Phantom Tollbooth The Phantom Tollbooth, b...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  Santa Claus: The Movie The first half of this ...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  Child's Play 3 It's been eight years since the...
# 40  Rabbit Hole Life for a happy couple is turned ...
# 41                                                NaN
# 42  Child's Play 2 Chuckie's back as the doll poss...
# 43                                                NaN
# 44                                                NaN
# 45  Tormented A jazz pianist (Richard Carlson) is ...
# 46                                                NaN
# 47                                                NaN
# 48  Puppet Master vs Demonic Toys A group of toyma...
# 49                                                NaN

# %%
# df.sort_values(by='popularity', ascending=False, key=lambda col: col.str.lower())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df.sort_values(by='popularity', ascending=False)
#
# File /Users/chandu/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Users/chandu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6324, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6321     if isinstance(ascending, (tuple, list)):
#    6322         ascending = ascending[0]
# -> 6324     indexer = nargsort(
#    6325         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6326     )
#    6327 else:
#    6328     return self.copy()
#
# File /Users/chandu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/sorting.py:417, in nargsort(items, kind, ascending, na_position, key, mask)
#     415     non_nans = non_nans[::-1]
#     416     non_nan_idx = non_nan_idx[::-1]
# --> 417 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     418 if not ascending:
#     419     indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
# import numpy as np
# import pandas as pd
# from flask import Flask, render_template, request
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# import json
# import bs4 as bs
# import urllib.request
# import pickle

# cv = CountVectorizer()
# count_matrix = cv.fit_transform(filteredData['Combination 1'])
# similarity = cosine_similarity(count_matrix)
